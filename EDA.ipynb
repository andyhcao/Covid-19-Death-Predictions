# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv('Data/train.csv')
train
# Out:
#                Id  Location  Weekly Cases  Year  Weekly Cases per Million  \
# 0       911530868     World        2372.0  2020                     0.300
# 1       807936902     World        5023.0  2020                     0.635
# 2       773590408     World        5612.0  2020                     0.710
# 3       130466459     World        7580.0  2020                     0.958
# 4       544040446     World        8983.0  2020                     1.136
# ...           ...       ...           ...   ...                       ...
# 129151  541829605  Zimbabwe         464.0  2022                    29.012
# 129152  969939474  Zimbabwe         471.0  2022                    29.449
# 129153  667902340  Zimbabwe         450.0  2022                    28.136
# 129154  961193720  Zimbabwe         277.0  2022                    17.320
# 129155  832612563  Zimbabwe         277.0  2022                    17.320
#
#         Weekly Deaths  Weekly Deaths per Million  Total Vaccinations  \
# ...

# %%
train['Location'].value_counts()
# Out:
# North America          679
# Upper middle income    678
# Philippines            675
# China                  674
# European Union         672
#                       ...
# Tonga                   84
# Samoa                   79
# Cook Islands            58
# North Korea             44
# Macao                    1
# Name: Location, Length: 224, dtype: int64

# %%
train['Year'].value_counts()
# Out:
# 2021    57515
# 2020    41444
# 2022    30197
# Name: Year, dtype: int64

# %%
train.groupby('Year').mean()
# Out:
#                 Id   Weekly Cases  Weekly Cases per Million  Weekly Deaths  \
# Year
# 2020  5.511817e+08   42837.938954                425.764538     990.350338
# 2021  5.507007e+08   76299.791715               1022.586635    1342.544707
# 2022  5.481543e+08  202898.168462               3362.265360     669.430260
#
#       Weekly Deaths per Million  Total Vaccinations  People Vaccinated  \
# Year
# 2020                   7.982709        7.164571e+05       4.650458e+05
# 2021                  14.061087        1.410097e+08       7.473558e+07
# 2022                   8.555170        4.804568e+08       2.154228e+08
#
#       People Fully Vaccinated  Total Boosters  Daily Vaccinations  \
# Year
# 2020             8.199230e+03    1.000000e+00        74279.474138
# 2021             5.485143e+07    6.645961e+06       558566.950278
# 2022             1.873369e+08    7.587129e+07       328903.193639
#
#       Total Vaccinations per Hundred  People Vaccinated per Hundred  \
# Year
# ...

# %%
train.groupby(['Location','Year']).mean().sort_values('Location')
# Out:
#                             Id   Weekly Cases  Weekly Cases per Million  \
# Location    Year
# Afghanistan 2020  5.368497e+08    1265.720183                 31.564537
#             2021  5.686148e+08    2020.658273                 50.391147
#             2022  5.569949e+08     909.693431                 22.685942
# Africa      2020  5.418974e+08   58057.898734                 41.696460
#             2021  5.475080e+08  134305.739623                 96.456675
# ...                        ...            ...                       ...
# Zambia      2020  5.614700e+08     505.466019                 25.957117
#             2022  5.755671e+08    3513.950355                180.451277
# Zimbabwe    2021  5.296313e+08    3578.047782                223.718546
#             2020  5.512417e+08     337.336842                 21.092089
#             2022  5.461161e+08    1932.284768                120.816702
#
#                   Weekly Deaths  Weekly Deaths per Million  \
# Location    Year
# ...

# %%
train['Weekly Cases'].describe()
# Out:
# count    1.289430e+05
# mean     9.520131e+04
# std      6.329716e+05
# min      0.000000e+00
# 25%      1.040000e+02
# 50%      1.084000e+03
# 75%      9.750000e+03
# max      2.406618e+07
# Name: Weekly Cases, dtype: float64

# %%
train['Weekly Deaths'].describe()
# Out:
# count    127898.000000
# mean       1072.815494
# std        5287.848128
# min           0.000000
# 25%           1.000000
# 50%          13.000000
# 75%         127.000000
# max      103568.000000
# Name: Weekly Deaths, dtype: float64

# %%
weekly_death_pct = train[train['Weekly Cases']!= 0]['Weekly Deaths']/train[train['Weekly Cases']!= 0]['Weekly Cases']
weekly_death_pct.describe()
# Out:
# count    121720.000000
# mean          0.024291
# std           0.092821
# min           0.000000
# 25%           0.001762
# 50%           0.010742
# 75%           0.025379
# max          11.081395
# dtype: float64

# %%
sns.heatmap(train.drop(['Id','Location','Year'],axis=1).corr(),annot=True)
plt.gcf().set_size_inches(13, 13)

# %% [markdown]
# Next Week's Death has strong correlation with daily people vaccinated daily vaccinations, weekly deaths and weekly cases.

# %%
sns.regplot(train['Weekly Deaths'],train["Next Week's Deaths"])
plt.gcf().set_size_inches(13,13)
# Out:
# C:\Users\Andy Hoang-Cao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(train['People Vaccinated'],train["Next Week's Deaths"])
plt.gcf().set_size_inches(18,12)
# Out:
# C:\Users\Andy Hoang-Cao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(train['Daily People Vaccinated'],train["Next Week's Deaths"])
plt.gcf().set_size_inches(18,12)
# Out:
# C:\Users\Andy Hoang-Cao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(train['Weekly Cases'],train["Next Week's Deaths"])
plt.gcf().set_size_inches(18,12)
# Out:
# C:\Users\Andy Hoang-Cao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(train['Weekly Cases'],train['Weekly Deaths'])
plt.gcf().set_size_inches(18,12)
# Out:
# C:\Users\Andy Hoang-Cao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train.isnull().sum()
# Out:
# Id                                          0
# Location                                    0
# Weekly Cases                              213
# Year                                        0
# Weekly Cases per Million                  868
# Weekly Deaths                            1258
# Weekly Deaths per Million                1909
# Total Vaccinations                      88886
# People Vaccinated                       90727
# People Fully Vaccinated                 92582
# Total Boosters                         109309
# Daily Vaccinations                      51316
# Total Vaccinations per Hundred          88886
# People Vaccinated per Hundred           90727
# People Fully Vaccinated per Hundred     92582
# Total Boosters per Hundred             109309
# Daily Vaccinations per Hundred          51316
# Daily People Vaccinated                 51765
# Daily People Vaccinated per Hundred     51765
# Next Week's Deaths                          0
# dtype: int64

# %%
for x in train.columns:
    count = (train[f'{x}']==0).sum()
    print(f'Number of zeroes in {x} column: ' + str(count))
# Out:
# Number of zeroes in Id column: 0
# Number of zeroes in Location column: 0
# Number of zeroes in Weekly Cases column: 6101
# Number of zeroes in Year column: 0
# Number of zeroes in Weekly Cases per Million column: 5475
# Number of zeroes in Weekly Deaths column: 29943
# Number of zeroes in Weekly Deaths per Million column: 29331
# Number of zeroes in Total Vaccinations column: 92
# Number of zeroes in People Vaccinated column: 91
# Number of zeroes in People Fully Vaccinated column: 0
# Number of zeroes in Total Boosters column: 0
# Number of zeroes in Daily Vaccinations column: 649
# Number of zeroes in Total Vaccinations per Hundred column: 256
# Number of zeroes in People Vaccinated per Hundred column: 283
# Number of zeroes in People Fully Vaccinated per Hundred column: 574
# Number of zeroes in Total Boosters per Hundred column: 3170
# Number of zeroes in Daily Vaccinations per Hundred column: 761
# Number of zeroes in Daily People Vaccinated column: 1565
# ...

# %% [markdown]
# Since the number of zeroes in these columns aren't zeroes, we cannot assume that the null values are zeroes.
